# %%
import pandas as pd 
# import matplotlib.pyplot as plt
# import seaborn as sns 
import requests
import geopandas as gpd
import scipy
import numpy as np 
import swifter
import geopy
from geopy.geocoders import Nominatim
from geopy.extra.rate_limiter import RateLimiter
import multiprocessing as mp
from tqdm import tqdm
import time 
tqdm.pandas()
# geolocator = Nominatim(user_agent="my-app", timeout=1000)

import googlemaps

# %%
from geopy.extra.rate_limiter import RateLimiter

def geocode_worker(address):
    API_KEY = 'AIzaSyC1OpXgUKxR-crksp1Y6XHjX-gomkaCcoM'

    gmaps = googlemaps.Client(API_KEY)
    results =   gmaps.geocode(address+', NY')
    f_result = {'formatted_address': results[0][u"formatted_address"].encode("utf-8"),'latitude' : results[0][u"geometry"][u"location"][u"lat"],'longitude' : results[0][u"geometry"][u"location"][u"lng"] }  

    return f_result

# %%
data = pd.read_csv('comparablerentals.csv')

data['chunk'] = data.index//1000

# %%
results2 = []

for i, chunk in tqdm(data.groupby('chunk')['Address']):
    if i > 0:
        results2.append(chunk.apply(geocode_worker))
#     break
# Out:
#   0%|          | 0/87 [00:00<?, ?it/s]
#
#
#   2%|▏         | 2/87 [03:22<2:23:35, 101.35s/it]
#
#
#   3%|▎         | 3/87 [06:01<2:45:50, 118.46s/it]
#
#
#   5%|▍         | 4/87 [07:47<2:38:58, 114.92s/it]
#
#
#   6%|▌         | 5/87 [09:38<2:35:10, 113.54s/it]
#
#
#   7%|▋         | 6/87 [11:54<2:42:31, 120.38s/it]
#
#
#   8%|▊         | 7/87 [14:31<2:55:08, 131.36s/it]
#
#
#   9%|▉         | 8/87 [17:04<3:01:34, 137.91s/it]
#
#
#  10%|█         | 9/87 [18:43<2:43:57, 126.12s/it]
#
#
#  11%|█▏        | 10/87 [19:50<2:19:05, 108.38s/it]
#
#
#  13%|█▎        | 11/87 [20:54<2:00:25, 95.07s/it]
#
#
#  14%|█▍        | 12/87 [22:06<1:50:15, 88.21s/it]
#
#
#  15%|█▍        | 13/87 [23:21<1:43:47, 84.15s/it]
#
#
#  16%|█▌        | 14/87 [24:54<1:45:39, 86.85s/it]
#
#
#  17%|█▋        | 15/87 [26:26<1:46:02, 88.37s/it]
#
#
#  18%|█▊        | 16/87 [28:10<1:50:14, 93.16s/it]
#
#
#  20%|█▉        | 17/87 [29:32<1:44:41, 89.74s/it]
#
#
#  21%|██        | 18/87 [30:57<1:41:48, 88.53s/it]
#
#
# ...

# %%
# len(results[0])
# Out:
# 1000

# %%
results2
# Out:
# [1000    {u'latitude': 40.8128508, u'formatted_address'...
#  1001    {u'latitude': 40.7359057, u'formatted_address'...
#  1002    {u'latitude': 40.7419867, u'formatted_address'...
#  1003    {u'latitude': 40.7419438, u'formatted_address'...
#  1004    {u'latitude': 40.734002, u'formatted_address':...
#  1005    {u'latitude': 40.7341766, u'formatted_address'...
#  1006    {u'latitude': 40.7317524, u'formatted_address'...
#  1007    {u'latitude': 40.7445546, u'formatted_address'...
#  1008    {u'latitude': 40.74764, u'formatted_address': ...
#  1009    {u'latitude': 40.7497028, u'formatted_address'...
#  1010    {u'latitude': 40.734024, u'formatted_address':...
#  1011    {u'latitude': 40.7315992, u'formatted_address'...
#  1012    {u'latitude': 40.7380357, u'formatted_address'...
#  1013    {u'latitude': 40.7388844, u'formatted_address'...
#  1014    {u'latitude': 40.7249134, u'formatted_address'...
#  1015    {u'latitude': 40.7235481, u'formatted_address'...
# ...

# %%
df = pd.concat([pd.DataFrame.from_dict(x)for x in results2])

# %%
df['latitude'] = df['Address'].apply(lambda x:x[u'latitude'])
df['longitude'] = df['Address'].apply(lambda x:x[u'longitude'])
df['formatted_address'] = df['Address'].apply(lambda x:x[u'formatted_address'])

# %%
df1 = pd.read_csv('output1.csv')

# %%
df1['latitude'] = df1['Address'].apply(lambda x:x['latitude'])
df1['longitude'] = df1['Address'].apply(lambda x:x['longitude'])
df1['formatted_address'] = df1['Address'].apply(lambda x:x['formatted_address'])
# Out:
# TypeErrorTraceback (most recent call last)
# <ipython-input-68-75d44b91adcc> in <module>()
# ----> 1 df1['latitude'] = df1['Address'].apply(lambda x:x['latitude'])
#       2 df1['longitude'] = df1['Address'].apply(lambda x:x['longitude'])
#       3 df1['formatted_address'] = df1['Address'].apply(lambda x:x['formatted_address'])
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/series.pyc in apply(self, func, convert_dtype, args, **kwds)
#    3589             else:
#    3590                 values = self.astype(object).values
# -> 3591                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3592
#    3593         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-68-75d44b91adcc> in <lambda>(x)
# ----> 1 df1['latitude'] = df1['Address'].apply(lambda x:x['latitude'])
#       2 df1['longitude'] = df1['Address'].apply(lambda x:x['longitude'])
# ...

# %%
df1
# Out:
#      Unnamed: 0                                            Address
# 0             0  {'latitude': 40.706074, 'formatted_address': '...
# 1             1  {'latitude': 40.7096248, 'formatted_address': ...
# 2             2  {'latitude': 40.7098261, 'formatted_address': ...
# 3             3  {'latitude': 40.7066593, 'formatted_address': ...
# 4             4  {'latitude': 40.7074532, 'formatted_address': ...
# 5             5  {'latitude': 40.7071929, 'formatted_address': ...
# 6             6  {'latitude': 40.7090088, 'formatted_address': ...
# 7             7  {'latitude': 40.7138923, 'formatted_address': ...
# 8             8  {'latitude': 40.708556, 'formatted_address': '...
# 9             9  {'latitude': 40.7090088, 'formatted_address': ...
# 10           10  {'latitude': 40.708556, 'formatted_address': '...
# 11           11  {'latitude': 40.7250926, 'formatted_address': ...
# 12           12  {'latitude': 40.7551253, 'formatted_address': ...
# ...

# %%
import re 
def get_coordinates(Address): 
    lat_match = re.find(r'latitude:+\b', Address).group(0)
    return lat_match

# %%
df1['Address'].apply(get_coordinates)
# Out:
# AttributeErrorTraceback (most recent call last)
# <ipython-input-88-d619e511fc09> in <module>()
# ----> 1 df1['Address'].apply(get_coordinates)
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/series.pyc in apply(self, func, convert_dtype, args, **kwds)
#    3589             else:
#    3590                 values = self.astype(object).values
# -> 3591                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3592
#    3593         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-87-b1707e56deb9> in get_coordinates(Address)
#       1 import re
#       2 def get_coordinates(Address):
# ----> 3     lat_match = re.find(r'latitude:+\b', Address).group(1)
#       4     return lat_match
#       5
#
# AttributeError: 'module' object has no attribute 'find'

# %%
# data.groupby('chunk').count()

# %%
# for chunk in tqdm(data.groupby('chunk')): 
# #     print(chunk[0])
#     addresses = (chunk[1]["Address"]+', NY').tolist()
# #     break
#     pool = mp.Pool(processes = (mp.cpu_count() - 1))

# # addresses = comparablerentals['Address'].iloc[0:10].values.tolist()
#     result = dict(zip(addresses, pool.map(geocode_worker, addresses)))
#     pd.DataFrame(result).T.to_csv('out_{}.csv'.format(chunk[0]),encoding = 'utf-8')
#     time.sleep(1)
# Out:
#   0%|          | 0/87 [00:00<?, ?it/s]
# GeocoderQuotaExceededTraceback (most recent call last)
# <ipython-input-21-3f99f0ad87bf> in <module>()
#       6
#       7 # addresses = comparablerentals['Address'].iloc[0:10].values.tolist()
# ----> 8     result = dict(zip(addresses, pool.map(geocode_worker, addresses)))
#       9     pd.DataFrame(result).T.to_csv('out_{}.csv'.format(chunk[0]),encoding = 'utf-8')
#      10     time.sleep(1)
#
# /usr/lib/python2.7/multiprocessing/pool.pyc in map(self, func, iterable, chunksize)
#     249         '''
#     250         assert self._state == RUN
# --> 251         return self.map_async(func, iterable, chunksize).get()
#     252
#     253     def imap(self, func, iterable, chunksize=1):
#
# /usr/lib/python2.7/multiprocessing/pool.pyc in get(self, timeout)
#     565             return self._value
#     566         else:
# --> 567             raise self._value
#     568
#     569     def _set(self, i, obj):
#
# ...
